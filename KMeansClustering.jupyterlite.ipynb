# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2022-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>
#
# # **Practice Lab: K Means Clustering Lab**
#
# Estimated time needed: **45** minutes

# %% [markdown]
# ## Objectives
#
# After completing this lab you will be able to:
#
# *   Explain the theory behind K Means Clustering
# *   Implement K Means Clustering to perform exploratory data analysis
# *   Perform Image segmentation using K Means

# %% [markdown]
# ***

# %%
# All Libraries required for this lab are listed below. The libraries pre-installed on Skills Network Labs are commented.
import piplite
await piplite.install(['skillsnetwork'])
# await piplite.install(['numpy', 'pandas', 'scikit-learn', 'matplotlib'])

# %% [markdown]
# ### Importing Required Libraries

# %%
# !pip install skillsnetwork
# Out:
# Requirement already satisfied: skillsnetwork in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (0.20.6)
# Requirement already satisfied: ipython in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from skillsnetwork) (7.31.1)
# Requirement already satisfied: ipywidgets<8,>=7 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from skillsnetwork) (7.6.5)
# Requirement already satisfied: requests<3,>=2 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from skillsnetwork) (2.23.0)
# Requirement already satisfied: tqdm<5,>=4 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from skillsnetwork) (4.64.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from ipywidgets<8,>=7->skillsnetwork) (5.7.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from ipywidgets<8,>=7->skillsnetwork) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from ipywidgets<8,>=7->skillsnetwork) (1.0.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from ipywidgets<8,>=7->skillsnetwork) (6.15.2)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from ipywidgets<8,>=7->skillsnetwork) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from ipywidgets<8,>=7->skillsnetwork) (3.5.2)
# Requirement already satisfied: pygments in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from ipython->skillsnetwork) (2.11.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from ipython->skillsnetwork) (0.18.1)
# Requirement already satisfied: backcall in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from ipython->skillsnetwork) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from ipython->skillsnetwork) (3.0.36)
# Requirement already satisfied: colorama in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from ipython->skillsnetwork) (0.4.6)
# Requirement already satisfied: pickleshare in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from ipython->skillsnetwork) (0.7.5)
# Requirement already satisfied: decorator in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from ipython->skillsnetwork) (5.1.1)
# Requirement already satisfied: matplotlib-inline in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from ipython->skillsnetwork) (0.1.6)
# Requirement already satisfied: setuptools>=18.5 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from ipython->skillsnetwork) (65.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from requests<3,>=2->skillsnetwork) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from requests<3,>=2->skillsnetwork) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from requests<3,>=2->skillsnetwork) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from requests<3,>=2->skillsnetwork) (1.25.11)
# Requirement already satisfied: debugpy>=1.0 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7->skillsnetwork) (1.5.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7->skillsnetwork) (7.4.9)
# Requirement already satisfied: packaging in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7->skillsnetwork) (22.0)
# Requirement already satisfied: nest-asyncio in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7->skillsnetwork) (1.5.6)
# Requirement already satisfied: pyzmq>=17 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7->skillsnetwork) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7->skillsnetwork) (6.2)
# Requirement already satisfied: psutil in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7->skillsnetwork) (5.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from jedi>=0.16->ipython->skillsnetwork) (0.8.3)
# Requirement already satisfied: jupyter-core in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7->skillsnetwork) (4.11.1)
# Requirement already satisfied: importlib-metadata>=3.6 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7->skillsnetwork) (4.11.3)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7->skillsnetwork) (4.17.3)
# Requirement already satisfied: fastjsonschema in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7->skillsnetwork) (2.16.2)
# Requirement already satisfied: wcwidth in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->skillsnetwork) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork) (6.4.8)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from importlib-metadata>=3.6->nbformat>=4.2.0->ipywidgets<8,>=7->skillsnetwork) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from importlib-metadata>=3.6->nbformat>=4.2.0->ipywidgets<8,>=7->skillsnetwork) (3.11.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<8,>=7->skillsnetwork) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<8,>=7->skillsnetwork) (0.18.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<8,>=7->skillsnetwork) (1.3.10)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<8,>=7->skillsnetwork) (5.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<8,>=7->skillsnetwork) (2.8.2)
# Requirement already satisfied: entrypoints in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<8,>=7->skillsnetwork) (0.4)
# Requirement already satisfied: pywin32>=1.0 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets<8,>=7->skillsnetwork) (305.1)
# Requirement already satisfied: nbconvert in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork) (6.5.4)
# Requirement already satisfied: argon2-cffi in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork) (21.3.0)
# Requirement already satisfied: jinja2 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork) (3.1.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork) (0.17.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork) (1.8.0)
# Requirement already satisfied: prometheus-client in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork) (0.14.1)
# Requirement already satisfied: six>=1.5 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<8,>=7->skillsnetwork) (1.16.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork) (21.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork) (2.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork) (4.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork) (1.5.0)
# Requirement already satisfied: bleach in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork) (4.1.0)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork) (0.5.13)
# Requirement already satisfied: defusedxml in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork) (0.7.1)
# Requirement already satisfied: lxml in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork) (4.9.1)
# Requirement already satisfied: tinycss2 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork) (1.2.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork) (0.8.4)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\fernanda januar\anaconda3\envs\cv\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork) (2.21)

# %%
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')

import skillsnetwork
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Introduction

# %% [markdown]
# K Means Clustering is an unsupervised machine learning algorithm that organizes data into distinct groups based on certain similarities. The principle underlying the algorithm is simple to understand and is a great introduction to the potential of unsupervised learning algorithms for exploratory data analysis. In this lab, we will brush up on the basic theory underlying the algorithm and then go ahead and apply it ourselves to a real problem.

# %% [markdown]
# ### About K Means
#
# | Pros                                                  | Cons                                            |
# | ----------------------------------------------------- | ----------------------------------------------- |
# | Easy to implement                                     | Must manually chose K                           |
# | Always converges to local minimum                     | Not guaranteed to find global minimum           |
# | Scales well to large datasets                         | May not perform well on data of varying density |
# | Generalizes to clusters of different shapes and sizes | Clusters are biased by outliers                 |

# %% [markdown]
# ### How does K Means Clustering work?

# %% [markdown]
# The KMeans algorithm is quite simple and can be broken down into the following steps:
#
# <ol>
#     <li>We specify the hyperparameter <code>k</code>, which refers to the number of clusters we want our data to be clustered into.</li>
#     <li>Then <code>k</code> centroids, or cluster-means, are initialized at random.</li>
#     <li>Finally, the optimal centroid locations are found. This is done by the following algorithmic loop:</li>
#     <ol>
#         <li><b>Assignment step:</b> Assign each data point to the nearest centroid (calculated as the squared distance from the data point to centroid).</li>
#         <li><b>Update step:</b> Recompute each centroid as the mean of the data points assigned to that cluster in the previous step.</li>
#     </ol>
#     <li>We repeat the above step until the centroid locations remain unchanged. This tells us the algorithm has converged on a local optima and gives us the final cluster assignments for that run.</li>
# </ol>

# %% [markdown]
# ## Example 1: Visual intuition
#
# Take a look at the following animation for some physical intuition of what's going on during each iteration.
#
# It shows several iterations of K Means Clustering (steps 3 & 4 in previous section) applied to a sample dataset with <code>k = 2</code> clusters.
#
# ![img](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML0187EN-SkillsNetwork/labs/module%203/images/KMeansClustering_example.gif)
#
# In each iteration, you can see the previous locations of the centroids (faded) and the their current location after they were moved to the mean of the data points assigned to that cluster. The data points are colored by the cluster they are assigned to after that iteration.
#
# Finally, on iteration 6; we see the centroids of the clusters remain unchanged - this means the KMeans algorithm has converged and finished.

# %% [markdown]
# ## Example 2: Segmenting Customer Data
#
# While the theory and implementation of these algorithms are fascinating in their own right, as data scientists we're driven by the insights we can uncover and the stories we can tell with data.
#
# Now more than ever, companies are making data driven business decisions, in part thanks to the massive increase of data available, as well as the availability of computational power to process and make sense of the data.
#
# Customer segmentation is a process where customers are grouped together based on some common characteristics. For example, customers can be divided based on age, gender, income, marital status, and others. Segmenting customers in this way can have several applications for a business. For instance, common characteristics of the most profitable customers can be identified and a tailored marketing strategy can be implemented to target them.
#
# Let's have a go at customer segmentation using the K Means Clustering algorithm.

# %% [markdown]
# ### Problem Statement
#
# Suppose you are a data scientist at MegaMind Sporting Goods Ltd.
#
# You've been tasked with segmenting customers into groups depending on their purchasing habits.
#
# Once you have this information, your colleague John will be able to generate clothing recommendations tailored for each customer group.

# %% [markdown]
# ### About the dataset
#
# We will explore a simple example of customer segmentation using the [Mall Customers](https://github.com/SteffiPeTaffy/machineLearningAZ/blob/master/Machine%20Learning%20A-Z%20Template%20Folder/Part%204%20-%20Clustering/Section%2024%20-%20K-Means%20Clustering/Mall_Customers.csv) dataset. This is an artificial dataset that contains data on customers of a shopping mall. In particular, the following features are given about each customer.
#
# *   **CustomerID** - A unique identifying number for each the customer
# *   **Gender**
# *   **Age**
# *   **Annual Income** - The annual income of the customer given in thousands of dollars
# *   **Spending Score** - A value given to the customer based on their spending habits, such as total spending and frequency. A higher value indicates a higher value customer for the mall

# %% [markdown]
# ### Loading the dataset

# %%
# Download the dataset and read it into a Pandas dataframe
await skillsnetwork.download('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML0187EN-SkillsNetwork/labs/module%203/data/CustomerData.csv')
df = pd.read_csv('CustomerData.csv', index_col=0)
df.head()
# Out:
# Downloading CustomerData.csv:   0%|          | 0/3979 [00:00<?, ?it/s]
# Saved as 'CustomerData.csv'
#             Gender  Age  Annual Income (k$)  Spending Score (1-100)
# CustomerID
# 1             Male   19                  15                      39
# 2             Male   21                  15                      81
# 3           Female   20                  16                       6
# 4           Female   23                  16                      77
# 5           Female   31                  17                      40

# %% [markdown]
# Let's take a peek at our dataset to ensure it was loaded properly.

# %% [markdown]
# ### Getting familiar with the data
#
# First, let's take a look at the data we have to gain a better general understanding of it before we attempt any clustering.
#
# Let's start by looking at the distributions of some of the features.

# %% [markdown]
# We can start by analyzing the ratio of male to female customers that were surveyed.

# %%
num_male = df[df['Gender'] == 'Male'].shape[0]
num_female = df[df['Gender'] == 'Female'].shape[0]
plt.pie(
    [num_male, num_female],
    labels=['Male', 'Female'],
    startangle=90,
    autopct='%1.f%%',
    colors=['lavender', 'thistle'])
plt.title('Gender of survey respondants')
plt.show()

# %% [markdown]
# We see that we have slightly more female respondents in our survey. Next let's plot histograms of the age and annual incomes of the customers.

# %%
plt.hist(df['Annual Income (k$)'], bins=10)
plt.xlabel('Annual Income (k$)')
plt.ylabel('Number of Customers')
plt.show()

# %% [markdown]
# Our distribution appears slightly skewed to the right. Not as many people are making over $100k per year.
#
# Let's take a look at people's annual income vs spending score:

# %%
X = df[['Annual Income (k$)', 'Spending Score (1-100)']]

plt.scatter(X[xlabel], X[ylabel])
plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.show()

# %% [markdown]
# This looks promising, we can see our customers seem to fall into \~5 categories:
#
# 1.  **Low** income, **high** spending.
# 2.  **High** income, **low** spending.
# 3.  **Low** income, **low** spending.
# 4.  **High** income, **low** spending.
# 5.  **Medium** income, **medium** spending.
#
# If we manage to segment our existing customers into these 5 categories, we will obtain exactly the information John requires:

# %% [markdown]
# ### Clusting the data using K Means
#
# Let's start clusting our data!
#
# To do so, we simply load the <code>sklearn.cluster.KMeans</code> object - with our desired number of clusters <code>k = 5</code>:

# %%
km = KMeans(n_clusters=5, random_state=42)
km.fit(X)
# Out:
# KMeans(n_clusters=5, random_state=42)

# %%
for label in np.unique(km.labels_):
    X_ = X[label == km.labels_]
    plt.scatter(X_['Annual Income (k$)'], X_['Spending Score (1-100)'], label=label)
    
plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.show()

# %% [markdown]
# Awesome! Our KMeans algorithm was able to correctly group our data into the 5 categories we initially noticed

# %% [markdown]
# ## Example 3: Image Segmentation
#
# Image segmentation is the process of locating objects and boundaries in an image.
#
# Various clustering can be used for this task.
#
# **How** is this done?:
#
# 1.  We cluster pixels using their brightness (grayscale) or rgb values (color).
# 2.  We replace each pixel with the average brightness or rgb value of pixels in their cluster.
#
# Let's look at an example using KMeans:

# %% [markdown]
# ### Loading the data
#
# Let's start by loading the data into a <code>numpy.array</code> and taking a look at the image:

# %%
await skillsnetwork.download('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML0187EN-SkillsNetwork/labs/module%203/images/cameraman.png')
img = plt.imread('cameraman.png')
print(f'The image is {img.shape[0]}px by {img.shape[1]}px')
plt.axis('off')
plt.imshow(img)
plt.show()
# Out:
# Downloading cameraman.png:   0%|          | 0/129781 [00:00<?, ?it/s]
# Saved as 'cameraman.png'
# The image is 490px by 487px

# %% [markdown]
# ### Segmenting the image using 2 clusters
#
# In this example we will segment our image into <code>k = 2</code> color-clusters:

# %%
k = 2

X = img.reshape(-1, 1)
km = KMeans(n_clusters=k, random_state=42)

# %%
km.fit(X)
# Out:
# KMeans(n_clusters=2, random_state=42)

# %% [markdown]
# Let's see our segmented image; once we replace each pixel with the mean of the cluster it belongs to:

# %%
seg = np.zeros(X.shape)
for i in range(k):
    seg[km.labels_ == i] = km.cluster_centers_[i]
seg = seg.reshape(img.shape)
plt.axis('off')
plt.imshow(seg)

# %% [markdown]
# Awesome! Even as a human we can still easily recognize our image after segmentation with <code>k = 2</code> colors.
#
# ### Converting to black and white
#
# Alternatively we may view the image in black and white:

# %%
seg = np.zeros(X.shape)
for i in range(k):
    seg[km.labels_ == i] = 255 if km.cluster_centers_[i] > 0.5 else 0
seg = seg.reshape(img.shape).astype(np.uint8)
plt.axis('off')
plt.imshow(seg)
plt.show()

# %% [markdown]
# ### Thank you for completing this lab!
#
# ## Author
#
# [David Pasternak](https://www.linkedin.com/in/david-pasternak-6b84a2208/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2022-01-01)
#
# [Sam Prokopchuk](https://www.linkedin.com/in/sam-prokopchuk-1908b21a0/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2022-01-01)
#
# ### Other Contributors
#
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By      | Change Description    |
# | ----------------- | ------- | --------------- | --------------------- |
# | 2022-03-28        | 0.1     | David Pasternak | Created Lab           |
# | 2022-05-10        | 0.2     | Sam Prokopchuk  | Complete Draft of Lab |
# |2022-07-18.        |0.2      |Svitlana K      | Review and edit|
#
# ## <h3 align="center"> © IBM Corporation 2022. All rights reserved. <h3/>
